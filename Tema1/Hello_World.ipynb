# %% [markdown]
# ## Carga de Bibliotecas

# %%
from langchain_openai import ChatOpenAI

# %% [markdown]
# ## Inicializar Modelo de Lenguaje

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature = 0.7)

# %% [markdown]
# ### Codigo

# %%
pregunta = "¿En que año llego el ser humano a la Luna por primera vez?"
print("Pregunta: ", pregunta)

respuesta = llm.invoke(pregunta)

print("Respuesta del modelo: ", respuesta.content)
# Out:
# Pregunta:  ¿En que año llego el ser humano a la Luna por primera vez?
# Respuesta del modelo:  El ser humano llegó a la Luna por primera vez el 20 de julio de 1969, durante la misión Apollo 11 de la NASA. Neil Armstrong y Buzz Aldrin fueron los astronautas que caminaron sobre la superficie lunar, mientras que Michael Collins permaneció en órbita lunar.
